# %% [markdown]
# <br>
# <h1 style="text-align: center; font-family: arial black; color: red"><b></b>Deep Learning: Artificial Neural Networks (ANN)<b></b></h1>
# <h2 style="text-align: center; color: red"><b>Project 1: Heart Attack Prediction<b></h2>
# <h4 style="text-align: center; color: red"><b>Prepared By : Rayyan Ahmed<b></h4>
# <br>
#
# ---
#
# <br>
#
# <h3 style="text-align: center;"><b>Project Introduction<b></h3>
#
# This project is aimed at predicting the likelihood of a heart attack based on various health parameters using an Artificial Neural Network (ANN). The model leverages advanced machine learning techniques to assist in early detection and prevention.
#
# <br>
#
# ---
#
# <br>
#
# <h3 style="text-align: center;"><b>Objective<b></h3>
#
# To develop a robust predictive model that can analyze patient data and predict the risk of a heart attack earlier, aiding in timely medical intervention.
#
# <br>
#
# ---
#
# <br>
#
# <h3 style="text-align: center;"><b>Libraries Used in Project<b></h3>
#
# - I have installed latest versions of TensorFlow and Keras in my envoirment through anaconda prompt.
# - Then I connected my envoirment to my updated jupyter notebook.
#
# <h3 style="text-align: center;"><b>Library Versions<b></h3>
#
# <table style="width: 100%; border-collapse: collapse; text-align: left;">
#   <thead>
#     <tr style="background-color: #f2f2f2;">
#       <th style="border: 1px solid #ddd; padding: 8px; text-align: center;">Library</th>
#       <th style="border: 1px solid #ddd; padding: 8px; text-align: center;">Version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="border: 1px solid #ddd; padding: 8px; text-align: center">NumPy</td>
#       <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">2.2.2</td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #ddd; padding: 8px; text-align: center">Pandas</td>
#       <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">2.2.3</td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #ddd; padding: 8px; text-align: center">Matplotlib</td>
#       <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">3.10.0</td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #ddd; padding: 8px; text-align: center">Seaborn</td>
#       <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">0.13.2</td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #ddd; padding: 8px; text-align: center">Scikit-learn</td>
#       <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">1.6.0</td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #ddd; padding: 8px; text-align: center">TensorFlow</td>
#       <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">2.18.0</td>
#     </tr>
#     <tr>
#       <td style="border: 1px solid #ddd; padding: 8px; text-align: center">Keras</td>
#       <td style="border: 1px solid #ddd; padding: 8px; text-align: center;">3.8.0</td>
#     </tr>
#   </tbody>
# </table>
#
# <br>
#
# # ________________________________________________________________________________________
#
# <h2 style="text-align: center;"><b>Lets Start<b></h2>
#
# # ________________________________________________________________________________________
#
#
# <br>

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white"><b>Importing Dataset<b></h2>
# <br>

# %%
import pandas as pd

dataset = pd.read_csv('ann heartattack prediction.csv')
dataset.tail(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %% [markdown]
# <br>
# <h1 style="text-align: center; color: red"><b>1. Analyzing Dataset<b></h1>
#
# - Pandas
#
# <br>

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white"><b>Dataset Info<b></h2>
# <br>

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white"><b>Dataset Details<b></h2>
# <br>

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
dataset.keys()
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
dataset.target.head(4)
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# Name: target, dtype: int64

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white"><b>Dataset Description<b></h2>
# <br>

# %%
dataset.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white"><b>Dataset Values<b></h2>
# <p style="text-align: center; color: white">Analyzing Occurences of each value of our dataset</p>
# <br>

# %%
dataset['thal'].value_counts()
# Out:
# thal
# 2    166
# 3    117
# 1     18
# 0      2
# Name: count, dtype: int64

# %%
dataset_columns = list(dataset.columns)
count = 1

for i in dataset_columns:
    print('_' * 50)
    print('\n')
    print(f'Column {count}: {i}\n{dataset[i].value_counts()}')
    count += 1
# Out:
# __________________________________________________
#
#
# Column 1: age
# age
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 62    11
# 44    11
# 56    11
# 60    11
# 64    10
# 41    10
# 63     9
# 67     9
# 65     8
# 53     8
# 61     8
# 45     8
# 43     8
# 42     8
# 55     8
# 66     7
# 48     7
# 50     7
# 46     7
# 49     5
# 47     5
# 68     4
# 39     4
# 35     4
# 70     4
# 40     3
# 69     3
# 38     3
# 71     3
# 37     2
# 34     2
# 29     1
# 74     1
# 76     1
# 77     1
# Name: count, dtype: int64
# __________________________________________________
#
#
# Column 2: sex
# sex
# 1    207
# 0     96
# Name: count, dtype: int64
# __________________________________________________
#
#
# Column 3: cp
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64
# __________________________________________________
#
#
# Column 4: trestbps
# trestbps
# 120    37
# 130    36
# 140    32
# 110    19
# 150    17
# 138    13
# 128    12
# 125    11
# 160    11
# 112     9
# 132     8
# 118     7
# 108     6
# 124     6
# 135     6
# 145     5
# 152     5
# 134     5
# 170     4
# 100     4
# 122     4
# 105     3
# 180     3
# 136     3
# 142     3
# 126     3
# 115     3
# 148     2
# 146     2
# 144     2
# 178     2
# 94      2
# 102     2
# 104     1
# 155     1
# 172     1
# 101     1
# 129     1
# 156     1
# 117     1
# 106     1
# 200     1
# 165     1
# 174     1
# 192     1
# 123     1
# 154     1
# 114     1
# 164     1
# Name: count, dtype: int64
# __________________________________________________
#
#
# Column 5: chol
# chol
# 204    6
# 234    6
# 197    6
# 212    5
# 269    5
#       ..
# 169    1
# 187    1
# 176    1
# 241    1
# 131    1
# Name: count, Length: 152, dtype: int64
# __________________________________________________
#
#
# Column 6: fbs
# fbs
# 0    258
# 1     45
# Name: count, dtype: int64
# __________________________________________________
#
#
# Column 7: restecg
# restecg
# 1    152
# 0    147
# 2      4
# Name: count, dtype: int64
# __________________________________________________
#
#
# Column 8: thalach
# thalach
# 162    11
# 163     9
# 160     9
# 173     8
# 152     8
#        ..
# 117     1
# 71      1
# 118     1
# 134     1
# 90      1
# Name: count, Length: 91, dtype: int64
# __________________________________________________
#
#
# Column 9: exang
# exang
# 0    204
# 1     99
# Name: count, dtype: int64
# __________________________________________________
#
#
# Column 10: oldpeak
# oldpeak
# 0.0    99
# 1.2    17
# 1.0    14
# 0.6    14
# 0.8    13
# 1.4    13
# 0.2    12
# 1.6    11
# 1.8    10
# 2.0     9
# 0.4     9
# 0.1     7
# 2.8     6
# 2.6     6
# 1.9     5
# 1.5     5
# 3.0     5
# 0.5     5
# 2.2     4
# 3.6     4
# 0.9     3
# 3.4     3
# 4.0     3
# 2.4     3
# 0.3     3
# 3.2     2
# 2.3     2
# 1.1     2
# 4.2     2
# 2.5     2
# 1.3     1
# 3.5     1
# 0.7     1
# 3.1     1
# 6.2     1
# 5.6     1
# 2.9     1
# 2.1     1
# 3.8     1
# 4.4     1
# Name: count, dtype: int64
# __________________________________________________
#
#
# Column 11: slope
# slope
# 2    142
# 1    140
# 0     21
# Name: count, dtype: int64
# __________________________________________________
#
#
# Column 12: ca
# ca
# 0    175
# 1     65
# 2     38
# 3     20
# 4      5
# Name: count, dtype: int64
# __________________________________________________
#
#
# Column 13: thal
# thal
# 2    166
# 3    117
# 1     18
# 0      2
# Name: count, dtype: int64
# __________________________________________________
#
#
# Column 14: target
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# <br>
# <h1 style="text-align: center; color: red"><b>2. Visualizing Dataset<b></h1>
#
# - Matplotlib
# - Seaborn
#
# <br>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

matplotlib.__version__, sns.__version__
# Out:
# ('3.10.0', '0.13.2')

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white"><b>Pairplot Values<b></h2>
# <h5 style="text-align: center; color: white">Plotting <b>pairplot</b> to see if values are overlapping or not</h5>
# <br>

# %%
plt.figure(figsize = (10,10))

columns_to_plot = ["age", "sex", "cp", "trestbps", "chol", "target"]
sns.pairplot(dataset[columns_to_plot], height=4, aspect=1.2, hue = 'target')
plt.show()

# %% [markdown]
# ####
# #### We can observe that data points are overlapping each other, hence we also need to scale our data
# ####

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white"><b>Box Plots<b></h2>
# <h5 style="text-align: center; color: white">We'll plot Box Plots of various columns to see their values distribution.</h5>
# <br>

# %%
plt.figure(figsize=(8, 2))
sns.boxplot(x=dataset['chol'], color='orange')
plt.title('Cholesterol Levels', fontsize=16)
plt.xlabel('Cholesterol')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 2))
sns.boxplot(x=dataset['trestbps'], color='orange')
plt.title('Resting Blood Pressure', fontsize=16)
plt.xlabel('Resting BP')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 2))
sns.boxplot(x=dataset['thalach'], color='orange')
plt.title('Max Heart Rate Achieve during Physical Activity', fontsize=16)
plt.xlabel('Max Heart Rate Achieved')
plt.grid()
plt.show()

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white"><b>Scatter Plot 1<b></h2>
# <h5 style="text-align: center; color: white">Plotting Scatter Plots to show relations between Age and Max Heart Rate Achieved</h5>
# <br>

# %%
plt.figure(figsize=(7, 4))
sns.scatterplot(data=dataset, x='age', y='thalach', hue='sex', palette='viridis', alpha = 1)
plt.title('Age vs Maximum Heart Rate (thalach)', fontsize=16)
plt.xlabel('Age')
plt.ylabel('Maximum Heart Rate (thalach)')
plt.legend(title='Sex', labels=['Female', 'Male'])
plt.grid()
plt.show()
print('\nObservations:\Here we can observe that age is inversly proportional to Max HR. As age increase, the max hr decreases.')
# Out:
# Observations:\Here we can observe that age is inversly proportional to Max HR. As age increase, the max hr decreases.

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white"><b>Scatter Plot 2<b></h2>
# <h5 style="text-align: center; color: white">Plotting Scatter Plots to show relations between Cholestrol Level and Oldpeak</h5>
# <br>

# %%
plt.figure(figsize=(7, 4))
sns.scatterplot(data=dataset, x='chol', y='oldpeak', hue='target', palette='viridis', s=100)
plt.title('Cholesterol vs Oldpeak', fontsize=16)
plt.xlabel('Cholesterol')
plt.ylabel('Oldpeak (ST Depression)')
plt.legend(title='Target (0 = No Heart Attack, 1 = Heart Attack)')
plt.grid()
plt.show()

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white"><b>HeatMap<b></h2>
# <br>

# %%
plt.figure(figsize=(10, 8))
correlation_matrix = dataset.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Feature Correlation Heatmap', fontsize=16)
plt.show()

# %% [markdown]
# <br>
# <h1 style="text-align: center; color: red"><b>3. Creating Training and Test DataSet<b></h1>
#
# - Scikit-Learn
#
# <br>

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white"><b>Seperating x and y variables<b></h2>
# <br>

# %%
x = dataset.drop(['target'], axis = 1)
y = dataset['target']

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white"><b>train_test_split<b></h2>
# <br>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((212, 13), (91, 13), (212,), (91,))

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white"><b>Scaling Data<b></h2>
# <br>

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# <br>
# <h1 style="text-align: center; color: red"><b>4. Creating Neural Network Model<b></h1>
#
# - Tensorflow
# - Keras
#
# <br>

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white"><b>Creating Neural Architecture through Sequential API<b></h2>
# <br>

# %%
input_shape = x_train.shape[1:]
input_shape
# Out:
# (13,)

# %%
input_shape = x_train.shape[1:]
input_shape
# Out:
# (13,)

# %%
model = Sequential()
model.add(Dense(activation = 'relu', units = 16, input_dim = 13, kernel_initializer = 'uniform'))
model.add(Dense(activation = 'relu', units = 12, kernel_initializer = 'uniform'))
model.add(Dense(activation = 'sigmoid', units = 1, kernel_initializer = 'uniform'))

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white"><b>Our Neural Architecture's Summary<b></h2>
# <br>

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 16)             │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 12)             │           204 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            13 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 441 (1.72 KB)
#  Trainable params: 441 (1.72 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white">Compiling and Fitting Neural Architecture<b><b></h2>
# <br>

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
history = model.fit(x_train, y_train, batch_size = 7, epochs = 10, validation_split = 0.3)
# Out:
# Epoch 1/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.6297 - loss: 0.6927 - val_accuracy: 0.5312 - val_loss: 0.6918
# Epoch 2/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5427 - loss: 0.6905 - val_accuracy: 0.5312 - val_loss: 0.6866
# Epoch 3/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6476 - loss: 0.6816 - val_accuracy: 0.7969 - val_loss: 0.6692
# Epoch 4/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8149 - loss: 0.6575 - val_accuracy: 0.8281 - val_loss: 0.6259
# Epoch 5/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8180 - loss: 0.6140 - val_accuracy: 0.7969 - val_loss: 0.5646
# Epoch 6/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8923 - loss: 0.5154 - val_accuracy: 0.8125 - val_loss: 0.4955
# Epoch 7/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8919 - loss: 0.4306 - val_accuracy: 0.7969 - val_loss: 0.4477
# Epoch 8/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8867 - loss: 0.4053 - val_accuracy: 0.8438 - val_loss: 0.4198
# Epoch 9/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8820 - loss: 0.3668 - val_accuracy: 0.8594 - val_loss: 0.4028
# Epoch 10/10
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9134 - loss: 0.3399 - val_accuracy: 0.8594 - val_loss: 0.3941

# %%
history.history
# Out:
# {'accuracy': [0.5810810923576355,
#   0.5675675868988037,
#   0.7229729890823364,
#   0.837837815284729,
#   0.8581081032752991,
#   0.8716216087341309,
#   0.8716216087341309,
#   0.8783783912658691,
#   0.8851351141929626,
#   0.8783783912658691],
#  'loss': [0.6924318075180054,
#   0.6889342069625854,
#   0.6770073175430298,
#   0.6442322731018066,
#   0.5807359218597412,
#   0.5027082562446594,
#   0.43097984790802,
#   0.38234835863113403,
#   0.3556097447872162,
#   0.3371131718158722],
#  'val_accuracy': [0.53125,
#   0.53125,
#   0.796875,
#   0.828125,
#   0.796875,
#   0.8125,
#   0.796875,
#   0.84375,
#   0.859375,
#   0.859375],
#  'val_loss': [0.691753089427948,
#   0.6865599751472473,
#   0.669206976890564,
#   0.6259072422981262,
#   0.5646363496780396,
#   0.49550291895866394,
#   0.4477294087409973,
#   0.4198299050331116,
#   0.40281417965888977,
#   0.3941400647163391]}

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white">Confusion Matrix of Our ANN Model<b><b></h2>
# <br>

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[34 10]
#  [ 4 43]]

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white">Classification Report of Our ANN Model<b><b></h2>
# <br>

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.77      0.83        44
#            1       0.81      0.91      0.86        47
#
#     accuracy                           0.85        91
#    macro avg       0.85      0.84      0.84        91
# weighted avg       0.85      0.85      0.85        91

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white">Putting Everything Together<b><b></h2>
#
# - Early Stopping
#
# <br>

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
# train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# scaling values
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# no. of input features
input_shape = x_train.shape[1:]
input_shape

# Neural Architecture
model = Sequential()
model.add(Dense(activation = 'relu', units = 14, input_dim = 13, kernel_initializer = 'uniform'))
model.add(Dense(activation = 'relu', units = 8, kernel_initializer = 'uniform'))
model.add(Dense(activation = 'relu', units = 4, kernel_initializer = 'uniform'))
model.add(Dense(activation = 'sigmoid', units = 1, kernel_initializer = 'uniform'))

# summary
model.summary()

# compiling
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

early_stopping = EarlyStopping(
    monitor='val_loss', # it monitors validation loss
    patience=15,         # these are Number of epochs to wait for improvement
    restore_best_weights=True)

# fitting
history = model.fit(x_train, y_train, batch_size = 16, epochs = 50, validation_split = 0.3, callbacks=[early_stopping])

# history
history.history

# y_pred
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5)

# confusion_matrix
print(confusion_matrix(y_test, y_pred))

# classification_report
print(classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 14)             │           196 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 8)              │           120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 357 (1.39 KB)
#  Trainable params: 357 (1.39 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.5762 - loss: 0.6931 - val_accuracy: 0.5342 - val_loss: 0.6929
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5783 - loss: 0.6925 - val_accuracy: 0.5342 - val_loss: 0.6926
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5963 - loss: 0.6917 - val_accuracy: 0.5342 - val_loss: 0.6920
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5811 - loss: 0.6909 - val_accuracy: 0.5342 - val_loss: 0.6909
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5530 - loss: 0.6902 - val_accuracy: 0.5342 - val_loss: 0.6887
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5025 - loss: 0.6889 - val_accuracy: 0.5342 - val_loss: 0.6841
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5529 - loss: 0.6820 - val_accuracy: 0.5342 - val_loss: 0.6757
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5434 - loss: 0.6711 - val_accuracy: 0.5342 - val_loss: 0.6625
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5957 - loss: 0.6526 - val_accuracy: 0.6575 - val_loss: 0.6433
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6931 - loss: 0.6415 - val_accuracy: 0.8082 - val_loss: 0.6196
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8358 - loss: 0.6048 - val_accuracy: 0.8082 - val_loss: 0.5900
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8610 - loss: 0.5888 - val_accuracy: 0.8219 - val_loss: 0.5590
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8836 - loss: 0.5349 - val_accuracy: 0.8219 - val_loss: 0.5321
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8409 - loss: 0.5409 - val_accuracy: 0.8356 - val_loss: 0.5103
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8176 - loss: 0.5344 - val_accuracy: 0.8356 - val_loss: 0.4923
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8332 - loss: 0.5186 - val_accuracy: 0.8219 - val_loss: 0.4766
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8388 - loss: 0.4936 - val_accuracy: 0.8356 - val_loss: 0.4606
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8535 - loss: 0.4445 - val_accuracy: 0.8219 - val_loss: 0.4464
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8643 - loss: 0.4096 - val_accuracy: 0.8356 - val_loss: 0.4318
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8477 - loss: 0.4330 - val_accuracy: 0.8630 - val_loss: 0.4173
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8495 - loss: 0.4011 - val_accuracy: 0.8630 - val_loss: 0.4045
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8514 - loss: 0.4258 - val_accuracy: 0.8493 - val_loss: 0.3922
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8500 - loss: 0.4275 - val_accuracy: 0.8493 - val_loss: 0.3840
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8814 - loss: 0.3684 - val_accuracy: 0.8493 - val_loss: 0.3765
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8643 - loss: 0.3683 - val_accuracy: 0.8493 - val_loss: 0.3711
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8995 - loss: 0.3129 - val_accuracy: 0.8493 - val_loss: 0.3671
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8888 - loss: 0.3165 - val_accuracy: 0.8493 - val_loss: 0.3644
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8884 - loss: 0.3267 - val_accuracy: 0.8493 - val_loss: 0.3621
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8885 - loss: 0.2934 - val_accuracy: 0.8493 - val_loss: 0.3606
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8757 - loss: 0.3070 - val_accuracy: 0.8493 - val_loss: 0.3592
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8617 - loss: 0.3424 - val_accuracy: 0.8493 - val_loss: 0.3574
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8974 - loss: 0.3081 - val_accuracy: 0.8493 - val_loss: 0.3552
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8690 - loss: 0.3115 - val_accuracy: 0.8493 - val_loss: 0.3553
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9002 - loss: 0.2921 - val_accuracy: 0.8493 - val_loss: 0.3543
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9177 - loss: 0.2788 - val_accuracy: 0.8356 - val_loss: 0.3532
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8597 - loss: 0.3844 - val_accuracy: 0.8356 - val_loss: 0.3529
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9195 - loss: 0.2441 - val_accuracy: 0.8356 - val_loss: 0.3533
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8960 - loss: 0.2976 - val_accuracy: 0.8356 - val_loss: 0.3527
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9030 - loss: 0.2909 - val_accuracy: 0.8356 - val_loss: 0.3530
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8867 - loss: 0.2994 - val_accuracy: 0.8356 - val_loss: 0.3521
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8738 - loss: 0.2974 - val_accuracy: 0.8356 - val_loss: 0.3527
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8877 - loss: 0.2856 - val_accuracy: 0.8356 - val_loss: 0.3527
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9184 - loss: 0.2329 - val_accuracy: 0.8356 - val_loss: 0.3530
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9109 - loss: 0.2937 - val_accuracy: 0.8493 - val_loss: 0.3519
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8887 - loss: 0.3256 - val_accuracy: 0.8356 - val_loss: 0.3512
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8856 - loss: 0.3306 - val_accuracy: 0.8493 - val_loss: 0.3498
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8875 - loss: 0.3072 - val_accuracy: 0.8493 - val_loss: 0.3495
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9036 - loss: 0.2908 - val_accuracy: 0.8630 - val_loss: 0.3495
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8976 - loss: 0.2740 - val_accuracy: 0.8493 - val_loss: 0.3505
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8912 - loss: 0.2907 - val_accuracy: 0.8493 - val_loss: 0.3501
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# [[23  4]
#  [ 3 31]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87        27
#            1       0.89      0.91      0.90        34
#
#     accuracy                           0.89        61
#    macro avg       0.89      0.88      0.88        61
# weighted avg       0.89      0.89      0.88        61

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white">Changing Number of Neurons to Get Higher Accuracy<b><b></h2>
# <br>

# %%
# train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# scaling values
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# no. of input features
input_shape = x_train.shape[1:]
input_shape

# Neural Architecture
model = Sequential()
model.add(Dense(activation = 'relu', units = 8, input_dim = 13, kernel_initializer = 'uniform'))
model.add(Dense(activation = 'relu', units = 8, kernel_initializer = 'uniform'))
model.add(Dense(activation = 'relu', units = 32, kernel_initializer = 'uniform'))
model.add(Dense(activation = 'sigmoid', units = 1, kernel_initializer = 'uniform'))

# summary
model.summary()

# compiling
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

early_stopping = EarlyStopping(
    monitor='val_loss', # it monitors validation loss
    patience=30,         # these are Number of epochs to wait for improvement
    restore_best_weights=True)

# fitting
history = model.fit(x_train, y_train, batch_size = 8, epochs = 50, validation_split = 0.3, callbacks=[early_stopping])

# history
history.history

# y_pred
y_pred = model.predict(x_test)
y_pred = (y_pred > 0.5)

# confusion_matrix
print(confusion_matrix(y_test, y_pred))

# classification_report
print(classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                │ (None, 8)              │           112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 32)             │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 505 (1.97 KB)
#  Trainable params: 505 (1.97 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.5198 - loss: 0.6931 - val_accuracy: 0.5342 - val_loss: 0.6929
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5829 - loss: 0.6926 - val_accuracy: 0.5479 - val_loss: 0.6919
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6768 - loss: 0.6914 - val_accuracy: 0.8356 - val_loss: 0.6856
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8021 - loss: 0.6832 - val_accuracy: 0.8356 - val_loss: 0.6609
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8440 - loss: 0.6476 - val_accuracy: 0.8493 - val_loss: 0.5974
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8606 - loss: 0.5687 - val_accuracy: 0.8356 - val_loss: 0.5242
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8631 - loss: 0.5209 - val_accuracy: 0.8630 - val_loss: 0.4754
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8572 - loss: 0.4704 - val_accuracy: 0.8630 - val_loss: 0.4394
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9153 - loss: 0.3784 - val_accuracy: 0.8630 - val_loss: 0.4212
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7647 - loss: 0.5106 - val_accuracy: 0.8630 - val_loss: 0.4033
# Epoch 11/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8029 - loss: 0.4788 - val_accuracy: 0.8493 - val_loss: 0.3819
# Epoch 12/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8526 - loss: 0.3774 - val_accuracy: 0.8767 - val_loss: 0.3730
# Epoch 13/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8409 - loss: 0.3764 - val_accuracy: 0.8767 - val_loss: 0.3679
# Epoch 14/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8459 - loss: 0.3802 - val_accuracy: 0.8767 - val_loss: 0.3631
# Epoch 15/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8098 - loss: 0.4032 - val_accuracy: 0.8630 - val_loss: 0.3624
# Epoch 16/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8728 - loss: 0.3456 - val_accuracy: 0.8630 - val_loss: 0.3632
# Epoch 17/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8820 - loss: 0.3277 - val_accuracy: 0.8630 - val_loss: 0.3610
# Epoch 18/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8839 - loss: 0.3344 - val_accuracy: 0.8630 - val_loss: 0.3620
# Epoch 19/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8571 - loss: 0.3710 - val_accuracy: 0.8767 - val_loss: 0.3612
# Epoch 20/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8690 - loss: 0.3726 - val_accuracy: 0.8630 - val_loss: 0.3670
# Epoch 21/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9097 - loss: 0.3176 - val_accuracy: 0.8630 - val_loss: 0.3626
# Epoch 22/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8761 - loss: 0.3787 - val_accuracy: 0.8630 - val_loss: 0.3648
# Epoch 23/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8902 - loss: 0.3053 - val_accuracy: 0.8630 - val_loss: 0.3692
# Epoch 24/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8924 - loss: 0.3241 - val_accuracy: 0.8356 - val_loss: 0.3676
# Epoch 25/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8922 - loss: 0.3368 - val_accuracy: 0.8356 - val_loss: 0.3731
# Epoch 26/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9161 - loss: 0.2633 - val_accuracy: 0.8219 - val_loss: 0.3779
# Epoch 27/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9189 - loss: 0.2908 - val_accuracy: 0.8356 - val_loss: 0.3727
# Epoch 28/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9210 - loss: 0.2863 - val_accuracy: 0.8356 - val_loss: 0.3700
# Epoch 29/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8858 - loss: 0.3444 - val_accuracy: 0.8356 - val_loss: 0.3698
# Epoch 30/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9336 - loss: 0.2456 - val_accuracy: 0.8493 - val_loss: 0.3709
# Epoch 31/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9061 - loss: 0.3096 - val_accuracy: 0.8493 - val_loss: 0.3714
# Epoch 32/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8848 - loss: 0.3355 - val_accuracy: 0.8493 - val_loss: 0.3693
# Epoch 33/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9019 - loss: 0.3129 - val_accuracy: 0.8356 - val_loss: 0.3694
# Epoch 34/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9371 - loss: 0.2603 - val_accuracy: 0.8356 - val_loss: 0.3730
# Epoch 35/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9228 - loss: 0.2357 - val_accuracy: 0.8356 - val_loss: 0.3718
# Epoch 36/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9087 - loss: 0.2969 - val_accuracy: 0.8356 - val_loss: 0.3747
# Epoch 37/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9270 - loss: 0.2679 - val_accuracy: 0.8356 - val_loss: 0.3722
# Epoch 38/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9185 - loss: 0.2646 - val_accuracy: 0.8493 - val_loss: 0.3758
# Epoch 39/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8968 - loss: 0.3174 - val_accuracy: 0.8493 - val_loss: 0.3794
# Epoch 40/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9181 - loss: 0.2619 - val_accuracy: 0.8493 - val_loss: 0.3788
# Epoch 41/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9001 - loss: 0.3131 - val_accuracy: 0.8356 - val_loss: 0.3790
# Epoch 42/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9200 - loss: 0.2785 - val_accuracy: 0.8356 - val_loss: 0.3768
# Epoch 43/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9263 - loss: 0.2413 - val_accuracy: 0.8356 - val_loss: 0.3803
# Epoch 44/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8879 - loss: 0.3460 - val_accuracy: 0.8356 - val_loss: 0.3800
# Epoch 45/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8741 - loss: 0.3389 - val_accuracy: 0.8356 - val_loss: 0.3826
# Epoch 46/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9058 - loss: 0.2627 - val_accuracy: 0.8356 - val_loss: 0.3828
# Epoch 47/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8976 - loss: 0.2894 - val_accuracy: 0.8356 - val_loss: 0.3849
# WARNING:tensorflow:5 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7dfa3e46d080> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# WARNING:tensorflow:6 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7dfa3e46d080> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# [[21  6]
#  [ 2 32]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.78      0.84        27
#            1       0.84      0.94      0.89        34
#
#     accuracy                           0.87        61
#    macro avg       0.88      0.86      0.86        61
# weighted avg       0.87      0.87      0.87        61

# %% [markdown]
# #### Our ANN Model is 92% accurate

# %% [markdown]
# <br>
# <h1 style="text-align: center; color: red"><b>5. Saving and Loading Neural Network Model<b></h1>
#
# - Pickle
# - OS
#
# <br>

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white">Saving Model<b><b></h2>
#
#
# <br>

# %%
import pickle as pkl
import os

# %% [markdown]
# ##### Saving our Model in this folder using keras extension

# %%
model.save('HAP Model.keras')

# %% [markdown]
# ##### Saving StandardScaler in folder

# %%
pkl.dump(scaler, open('HAPM_StandardScaler.pkl', 'wb'))

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white">Loading our Saved Model<b><b></h2>
# <br>

# %%
from tensorflow.keras.models import load_model

loaded_model = load_model('HAP Model.keras')

# Load the scaler
with open('HAPM_StandardScaler.pkl', 'rb') as file:
    load_scaler = pkl.load(file)

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white">Model and Scaler are Loaded and are Ready to Use<b><b></h2>
# <br>

# %%
loaded_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                │ (None, 8)              │           112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 32)             │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,517 (5.93 KB)
#  Trainable params: 505 (1.97 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,012 (3.96 KB)

# %%
load_scaler
# Out:
# StandardScaler()

# %% [markdown]
# <br>
# <h2 style="text-align: center; color: white">x-x-x<b><b></h2>
# <br><br><br><br><br>

# %% [markdown]
# #### Thanks for watching
